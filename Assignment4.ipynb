# %%
#----------- remove_adjacent ----------------------
def remove_adjacent(nums):
    lstToReturn = []
    for num in nums:
        if num not in lstToReturn:
            lstToReturn.append(num)
    return lstToReturn

print("Calling remove_adjacent() Method")
print(remove_adjacent([1,2,2,3,4,3,5,1]))

#----------- linear_merge ----------------------
def linear_merge(list1, list2):
  return(sorted(list1 + list2))

print("\n","Calling linear_merge() Method")
print(linear_merge(['aa', 'xx', 'zz'], ['bb', 'cc']))
print("\n")

def test(got, expected):
    if got == expected:
        prefix = ' OK '
    else:
        prefix = '  X '
    print ('%s got: %s expected: %s' % (prefix, repr(got), repr(expected)))


# Calls the above functions with interesting inputs.
def main():
    print ('remove_adjacent')
    test(remove_adjacent([1, 2, 2, 3]), [1, 2, 3])
    test(remove_adjacent([2, 2, 3, 3, 3]), [2, 3])
    test(remove_adjacent([]), [])
    
    print ()
    print ('remove_adjacent -- With Wrong Expectation','\n')
    test(remove_adjacent([1, 2, 2, 3,4,5,4]), [1, 2, 3])
    test(remove_adjacent([1, 2, 2, 3, 3, 3]), [2, 3])
    test(remove_adjacent([]), [0])

    print()
    print ('linear_merge')
    test(linear_merge(['aa', 'xx', 'zz'], ['bb', 'cc']),['aa', 'bb', 'cc', 'xx', 'zz'])
    test(linear_merge(['aa', 'xx'], ['bb', 'cc', 'zz']),['aa', 'bb', 'cc', 'xx', 'zz'])
    test(linear_merge(['aa', 'aa'], ['aa', 'bb', 'bb']),['aa', 'aa', 'aa', 'bb', 'bb'])

    print()
    print ('linear_merge -- With Wrong Expectation','\n')
    test(linear_merge(['aa', 'bb', 'xx', 'zz'], ['bb', 'cc']),['aa', 'bb', 'cc', 'xx', 'zz'])
    test(linear_merge(['aa', 'kk', 'xx'], ['bb', 'cc', 'zz']),['aa', 'bb', 'cc', 'xx', 'zz'])
    test(linear_merge(['aa', 'bb', 'aa'], ['aa', 'bb', 'bb']),['aa', 'aa', 'aa', 'bb', 'bb'])


if __name__ == '__main__':
    main()
# Out:
# Calling remove_adjacent() Method
# [1, 2, 3, 4, 5]
#
#  Calling linear_merge() Method
# ['aa', 'bb', 'cc', 'xx', 'zz']
#
#
# remove_adjacent
#  OK  got: [1, 2, 3] expected: [1, 2, 3]
#  OK  got: [2, 3] expected: [2, 3]
#  OK  got: [] expected: []
#
# remove_adjacent -- With Wrong Expectation
#
#   X  got: [1, 2, 3, 4, 5] expected: [1, 2, 3]
#   X  got: [1, 2, 3] expected: [2, 3]
#   X  got: [] expected: [0]
#
# linear_merge
#  OK  got: ['aa', 'bb', 'cc', 'xx', 'zz'] expected: ['aa', 'bb', 'cc', 'xx', 'zz']
#  OK  got: ['aa', 'bb', 'cc', 'xx', 'zz'] expected: ['aa', 'bb', 'cc', 'xx', 'zz']
#  OK  got: ['aa', 'aa', 'aa', 'bb', 'bb'] expected: ['aa', 'aa', 'aa', 'bb', 'bb']
#
# linear_merge -- With Wrong Expectation
#
#   X  got: ['aa', 'bb', 'bb', 'cc', 'xx', 'zz'] expected: ['aa', 'bb', 'cc', 'xx', 'zz']
#   X  got: ['aa', 'bb', 'cc', 'kk', 'xx', 'zz'] expected: ['aa', 'bb', 'cc', 'xx', 'zz']
#   X  got: ['aa', 'aa', 'aa', 'bb', 'bb', 'bb'] expected: ['aa', 'aa', 'aa', 'bb', 'bb']
